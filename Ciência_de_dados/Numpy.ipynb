# %%
import numpy as np

# %%
# criar primeiro vetor
a = np.array([2,3,5,7,11]) 
a

# %%
#ndim número de dimensões do array
a.ndim
# Out:
# 1

# %%
#shape formato do array
a.shape
# Out:
# (5,)

# %%
b = np.array([[10, 20],
             [30, 40],
             [50,60]])
b
# Out:
# array([[10, 20],
#        [30, 40],
#        [50, 60]])

# %%
print(b.ndim)
print(b.shape)
# Out:
# 2
# (3, 2)

# %%
 b[2,1]
# Out:
# 60

# %%
b[1,0] = 23
b
# Out:
# array([[10, 20],
#        [23, 40],
#        [50, 60]])

# %%
#array com zeros
a = np.zeros((2,2))
a
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
#array com um
a = np.ones((3,3))
a
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
#random
a = np.random.random((3,2))
a
# Out:
# array([[0.28367732, 0.10861223],
#        [0.68347721, 0.81660295],
#        [0.61320398, 0.93502853]])

# %%
#randoint
a = np.random.randint(20, size=(3,3,3))
a
# Out:
# array([[[ 4, 19, 17],
#         [ 4, 11, 11],
#         [18,  0, 18]],
#
#        [[ 3, 16, 19],
#         [ 5,  3, 17],
#         [ 7,  6, 11]],
#
#        [[ 4, 13, 15],
#         [12,  9,  8],
#         [ 0, 14,  0]]])

# %%
# vetor 
a = np.arange(5)
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
print(a)
# Out:
# [0 1 2 3 4]
